# %% [markdown]
# ## Amber Alert Greece - Παπαχρήστου Σοφία
#
# https://www.hamogelo.gr/gr/el/eksafanismena-paidia:ambert-alert-hellas/
#
# Όλα τα τρέχοντα περιστατικά εξαφάνισης του ελληνικού Amber Alert δεν βρίσκονται σε σελίδες το ένα κάτω από το άλλο. Βρίσκονται στο παραπάνω σύνδεσμο σε κινούμενο carousel το ένα δίπλα στο άλλο, με μόνη πληροφορία το url από ένα αναδυόμενο παράθυρο. Θα προσπαθήσω να πάρω το url για κάθε εξαφανισμένο παιδί και ανοίγοντας το θα παίρνω κάθε φορά από το κείμενο τις πληροφόρίες που θα φτιάξουν τις στήλες μου.

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.rcParams['pdf.fonttype'] = 42
import numpy as np
import requests
import time

# %%
req = Request('https://www.hamogelo.gr/gr/el/eksafanismena-paidia:ambert-alert-hellas/', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
amber_alert = BeautifulSoup(webpage, "html.parser")

# %% [markdown]
# ##1. Βρίσκω τα urls εξαφάνισης

# %%
#θα αποθηκεύσω όλα τα url που θα βρω σε λίστα
child_url= []

images_box = amber_alert.find('div', attrs={'id': 'missingchildren_carousel'})
for link in images_box.findAll("a"):
    #print(link.get('data-href'))
    child_url.append(link.get('data-href'))

# %%
child_url
# Out:
# ['https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/255/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/254/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/248/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/250/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/246/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/247/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/244/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/243/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/226/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/197/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/188/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/199/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/161/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/158/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/141/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/140/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/137/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/134/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/130/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/136/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/121/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/117/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/138/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/2/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/37/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/38/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/39/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/40/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/41/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/42/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/43/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/44/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/45/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/46/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/47/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/48/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/49/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/50/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/51/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/52/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/53/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/54/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/55/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/56/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/57/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/58/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/59/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/60/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/61/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/63/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/64/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/65/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/66/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/67/',
#  'https://www.hamogelo.gr/gr/el/ajax/missingchildren:details-modal/68/']

# %%
#βλέπω πόσες είναι οι δημοσιεύσεις για αγνοούμενα παιδιά
print(len(child_url))
# Out:
# 55

# %% [markdown]
# ##2. Κάνω scrape κάθε url
# Από κάθε τέτοιο λινκ από την λίστα child_url, τώρα θα βρω και θα πάρω πληροφορίες για κάθε παιδι

# %%
child_info= []

for url in child_url:
  report_html = urlopen(url).read()
  report_doc = BeautifulSoup(report_html, "html.parser")
  info = report_doc.find('ul', class_= "clearfix")

  for link in info.findAll('span'):
    #print(link.text)
    child_info.append(link.text)

# %%
child_info
# Out:
# ['Όνομα : ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.',
#  'Ημερομηνία εξαφάνισης : 21 Ιανουαρίου 2022',
#  'Ημερομηνία Γέννησης : 02 Οκτωβρίου 2008',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ ΚΟΝΤΑ ',
#  'Όνομα : ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ',
#  'Ημερομηνία εξαφάνισης : 13 Ιανουαρίου 2022',
#  'Ημερομηνία Γέννησης : 28 Απριλίου 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΧΙΤΖΑΖΙ ΑΘΗΝΑ',
#  'Ημερομηνία εξαφάνισης : 21 Νοεμβρίου 2021',
#  'Ημερομηνία Γέννησης : 23 Φεβρουαρίου 2017',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ ΜΑΚΡΙΑ',
#  'Όνομα : ΑΛΕΞΑΝΔΡΟΣ Δ.',
#  'Ημερομηνία εξαφάνισης : 19 Νοεμβρίου 2021',
#  'Ημερομηνία Γέννησης : 15 Ιανουαρίου 2008',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΜΙΧΑΗΛ Γ.',
#  'Ημερομηνία εξαφάνισης : 17 Νοεμβρίου 2021',
#  'Ημερομηνία Γέννησης : 08 Απριλίου 2006',
#  'Χρώμα Ματιών : ΜΠΛΕ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : ΣΑΛΗ Σ.',
#  'Ημερομηνία εξαφάνισης : 14 Νοεμβρίου 2021',
#  'Ημερομηνία Γέννησης : 10 Μαρτίου 2007',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΟΚΚΙΝΑ',
#  'Όνομα : ΣΤΑΜΑΤΙΝΑ Σ.',
#  'Ημερομηνία εξαφάνισης : 15 Οκτωβρίου 2021',
#  'Ημερομηνία Γέννησης : 01 Νοεμβρίου 2005',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΣΑΧΑΜΠ ΖΑΝΤΑ ΜΠΙΜΠΙ ΑΜΙΝΑ',
#  'Ημερομηνία εξαφάνισης : 25 Σεπτεμβρίου 2021',
#  'Ημερομηνία Γέννησης : 28 Απριλίου 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΜΙΑ ΜΑΡΙΑΜ',
#  'Ημερομηνία εξαφάνισης : 02 Μαίου 2021',
#  'Ημερομηνία Γέννησης : 13 Αυγούστου 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΙΖΑΜΠΕΛΑ-ΕΛΕΝΑ (ον.) Σ.(επ.)',
#  'Ημερομηνία εξαφάνισης : 15 Οκτωβρίου 2020',
#  'Ημερομηνία Γέννησης : 30 June 2006',
#  'Χρώμα Ματιών : ΜΑΥΡΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : ΡΑΦΑΗΛΙΑ Ε.',
#  'Ημερομηνία εξαφάνισης : 24 Αυγούστου 2020',
#  'Ημερομηνία Γέννησης : 13 Φεβρουαρίου 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΜΠΕΡΧΟ(επ.) ΑΧΜΑΝΤ(ον.)',
#  'Ημερομηνία εξαφάνισης : 20 June 2020',
#  'Ημερομηνία Γέννησης : 01 Σεπτεμβρίου 2015',
#  'Χρώμα Ματιών : ',
#  'Χρώμα Μαλλιών : ',
#  'Όνομα : ΝΙΑΖΙ (ΕΠΩΝΥΜΟ) ΣΑΜΙΡ(ΟΝΟΜΑ)',
#  'Ημερομηνία εξαφάνισης : 23 Δεκεμβρίου 2019',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2007',
#  'Χρώμα Ματιών : ΜΑΥΡΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : BAHROUZ(ον.) KHOSHNAW (επ.)',
#  'Ημερομηνία εξαφάνισης : 09 Δεκεμβρίου 2019',
#  'Ημερομηνία Γέννησης : 02 Απριλίου 2007',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : ΣΑΦΝΤΑΡ ΑΧΜΑΝΤΙ',
#  'Ημερομηνία εξαφάνισης : 18 Αυγούστου 2019',
#  'Ημερομηνία Γέννησης : 21 Μαρτίου 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : HASHEMI SHOKROLLAH',
#  'Ημερομηνία εξαφάνισης : 05 Αυγούστου 2019',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2003',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΒΑΜΜΕΝΑ ΚΟΚΚΙΝΑ',
#  'Όνομα : ΜΟΧΙΣΑ ΧΟΡΜΑΤ',
#  'Ημερομηνία εξαφάνισης : 02 Ιουλίου 2019',
#  'Ημερομηνία Γέννησης : 21 Ιανουαρίου 2003',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ',
#  'Όνομα : ΜΟΥΚΤΑΡ ΤΑΜΠΙΣ',
#  'Ημερομηνία εξαφάνισης : 20 Απριλίου 2019',
#  'Ημερομηνία Γέννησης : 13 Φεβρουαρίου 2004',
#  'Χρώμα Ματιών : ΜΑΥΡΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : ΑΝΕΛΙΑ Ν.',
#  'Ημερομηνία εξαφάνισης : 10 Απριλίου 2019',
#  'Ημερομηνία Γέννησης : 17 Νοεμβρίου 2004',
#  'Χρώμα Ματιών : ΜΑΥΡΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : ΑΧΜΕΝΤ ΝΑΣΤΕΧΑ',
#  'Ημερομηνία εξαφάνισης : 03 Φεβρουαρίου 2019',
#  'Ημερομηνία Γέννησης : 02 Φεβρουαρίου 2003',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ',
#  'Όνομα : ΓΙΟΥΣΕΦ ΟΣΣΟ',
#  'Ημερομηνία εξαφάνισης : 03 Ιουλίου 2018',
#  'Ημερομηνία Γέννησης : 19 Ιουλίου 2006',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΧΛΟΥΝΤ ΑΪΟΜΠΑΪΝΤΙ',
#  'Ημερομηνία εξαφάνισης : 21 Μαίου 2018',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2003',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΜΑΥΡΑ',
#  'Όνομα : AYA MOHAMMED OLEIWI ',
#  'Ημερομηνία εξαφάνισης : 01 Νοεμβρίου 2016',
#  'Ημερομηνία Γέννησης : 23 June 2006',
#  'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#  'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ',
#  'Όνομα : ΤΡΑΪΑΝ-ΝΤΑΤΣΙΟΥ Κ.',
#  'Ημερομηνία εξαφάνισης : 14 Απριλίου 2016',
#  'Ημερομηνία Γέννησης : 02 Φεβρουαρίου 2003',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΝΑΣΤΑΡΑΝ ΧΕΪΝΤΑΡΙ',
#  'Ημερομηνία εξαφάνισης : 22 Ιανουαρίου 2016',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2009',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΑΜΙΡ ΓΙΑΣΙΜ ΣΑΜΟ',
#  'Ημερομηνία εξαφάνισης : 10 Δεκεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 11 Φεβρουαρίου 2003',
#  'Χρώμα Ματιών : Καφέ',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΡΟΝΤΕΡ ΟΘΜΑΝ',
#  'Ημερομηνία εξαφάνισης : 11 Νοεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 10 Φεβρουαρίου 2011',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΑΛΝΤ ΟΘΜΑΝ',
#  'Ημερομηνία εξαφάνισης : 11 Νοεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 03 Ιανουαρίου 2010',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΡΟΝΤΙ ΤΖΑΜΙΛ',
#  'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#  'Ημερομηνία Γέννησης : 05 Ιουλίου 2005',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΣΟΛΙΝ ΤΖΑΜΙΛ',
#  'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#  'Ημερομηνία Γέννησης : 01 Νοεμβρίου 2007',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΡΟΝΙ ΤΖΑΜΙΛ',
#  'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#  'Ημερομηνία Γέννησης : 15 Ιανουαρίου 2009',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΜΑΣΣΟΥΝ ΤΖΑΜΙΛ',
#  'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#  'Ημερομηνία Γέννησης : 09 Σεπτεμβρίου 2009',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΜΟΧΑΜΑΝΤ ΤΖΑΜΙΛ',
#  'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2011',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα : ΜΟΧΑΜΕΤ και ΑΜΠΑΣ ΑΛΚΑΦΑΝΤΖΙ',
#  'Ημερομηνία εξαφάνισης : 13 Σεπτεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 10 Σεπτεμβρίου 2010',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΑΓΙΑ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#  'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 01 Απριλίου 2002',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΣΑΓΙΑΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#  'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 05 Νοεμβρίου 2007',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΑΧΜΕΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#  'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#  'Ημερομηνία Γέννησης : 20 Απριλίου 2004',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΟΛΙΒΙΑ ΕΝΘΙΝΑΣ ΧΛΟΝΤ',
#  'Ημερομηνία εξαφάνισης : 31 Δεκεμβρίου 2011',
#  'Ημερομηνία Γέννησης : 25 Απριλίου 2008',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : LEONG JIN KUOK',
#  'Ημερομηνία εξαφάνισης : 27 Σεπτεμβρίου 2011',
#  'Ημερομηνία Γέννησης : 22 Αυγούστου 1983',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : BENEDETTA BIENAIME',
#  'Ημερομηνία εξαφάνισης : 15 Απριλίου 2011',
#  'Ημερομηνία Γέννησης : 30 Οκτωβρίου 2006',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ALESSIA SCHEPP',
#  'Ημερομηνία εξαφάνισης : 30 Ιανουαρίου 2011',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2005',
#  'Χρώμα Ματιών : Πράσινα',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα : LIVIA SCHEPP',
#  'Ημερομηνία εξαφάνισης : 30 Ιανουαρίου 2011',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2005',
#  'Χρώμα Ματιών : Μπλε',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα : SAMEEM FAZLI',
#  'Ημερομηνία εξαφάνισης : 14 Ιουλίου 2009',
#  'Ημερομηνία Γέννησης : 24 Δεκεμβρίου 2000',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : MATEO DULLIA',
#  'Ημερομηνία εξαφάνισης : 07 Σεπτεμβρίου 2008',
#  'Ημερομηνία Γέννησης : 28 Σεπτεμβρίου 2007',
#  'Χρώμα Ματιών : Γκριζοπράσινα',
#  'Χρώμα Μαλλιών : Καστανά ανοιχτά',
#  'Όνομα : ANDREA LIPONI',
#  'Ημερομηνία εξαφάνισης : 31 Μαίου 2008',
#  'Ημερομηνία Γέννησης : 02 Αυγούστου 1986',
#  'Χρώμα Ματιών : -',
#  'Χρώμα Μαλλιών : -',
#  'Όνομα : ZAHRA MOSA',
#  'Ημερομηνία εξαφάνισης : 16 Φεβρουαρίου 2008',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 1994',
#  'Χρώμα Ματιών : Μαύρα',
#  'Χρώμα Μαλλιών : Μαύρα',
#  'Όνομα : ΧΑΛΙΛ ΑΛΕΙΣΑ',
#  'Ημερομηνία εξαφάνισης : 22 June 2007',
#  'Ημερομηνία Γέννησης : 05 Ιανουαρίου 1990',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : MADELEINE McCANN',
#  'Ημερομηνία εξαφάνισης : 03 Μαίου 2007',
#  'Ημερομηνία Γέννησης : 12 Μαίου 2003',
#  'Χρώμα Ματιών : Πράσινα',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα : SIMON ANDREEA',
#  'Ημερομηνία εξαφάνισης : 15 Δεκεμβρίου 2005',
#  'Ημερομηνία Γέννησης : 01 Ιανουαρίου 1996',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΝΤΕΝΙΣ ΠΙΠΙΤΟΝ',
#  'Ημερομηνία εξαφάνισης : 01 Σεπτεμβρίου 2004',
#  'Ημερομηνία Γέννησης : 26 Οκτωβρίου 2000',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΑΡΤΟΥΡ ΤΣΑΡΙΑ',
#  'Ημερομηνία εξαφάνισης : 09 Ιουλίου 2004',
#  'Ημερομηνία Γέννησης : 12 Αυγούστου 1995',
#  'Χρώμα Ματιών : Καφέ σκούρα',
#  'Χρώμα Μαλλιών : Καστανά',
#  'Όνομα : ΘΕΜΙΣΤΟΚΛΗΣ ΕΥΘΥΜΙΑΔΗΣ',
#  'Ημερομηνία εξαφάνισης : 30 June 2000',
#  'Ημερομηνία Γέννησης : 28 Οκτωβρίου 1984',
#  'Χρώμα Ματιών : Γαλάζια',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα :  ΓΕΩΡΓΙΟΣ ΠΑΡΑΣΚΕΥΟΠΟΥΛΟΣ',
#  'Ημερομηνία εξαφάνισης : 24 June 1992',
#  'Ημερομηνία Γέννησης : 05 Μαρτίου 1982',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανόξανθα',
#  'Όνομα : BEN NEEDHAM',
#  'Ημερομηνία εξαφάνισης : 24 Ιουλίου 1991',
#  'Ημερομηνία Γέννησης : 29 Οκτωβρίου 1989',
#  'Χρώμα Ματιών : Γαλανά',
#  'Χρώμα Μαλλιών : Ξανθά',
#  'Όνομα : ΑΝΝΑ ΤΡΙΑΝΤΑΦΥΛΛΙΔΟΥ',
#  'Ημερομηνία εξαφάνισης : 19 Αυγούστου 1981',
#  'Ημερομηνία Γέννησης : 26 June 1979',
#  'Χρώμα Ματιών : Καστανά',
#  'Χρώμα Μαλλιών : Καστανά']

# %% [markdown]
# Λοιπόν βλέπω ότι η λίστα child_info είναι ενιαία. Για αυτό και θα την σπάσω ανα παιδί.

# %%
x = [i for i, s in enumerate(child_info) if s.startswith('Όνομα')]
y = x[1:] + [len(child_info)]
z = [child_info[i:j] for i, j in zip(x, y)]

z
# Out:
# [['Όνομα : ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.',
#   'Ημερομηνία εξαφάνισης : 21 Ιανουαρίου 2022',
#   'Ημερομηνία Γέννησης : 02 Οκτωβρίου 2008',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ ΚΟΝΤΑ '],
#  ['Όνομα : ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ',
#   'Ημερομηνία εξαφάνισης : 13 Ιανουαρίου 2022',
#   'Ημερομηνία Γέννησης : 28 Απριλίου 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΧΙΤΖΑΖΙ ΑΘΗΝΑ',
#   'Ημερομηνία εξαφάνισης : 21 Νοεμβρίου 2021',
#   'Ημερομηνία Γέννησης : 23 Φεβρουαρίου 2017',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ ΜΑΚΡΙΑ'],
#  ['Όνομα : ΑΛΕΞΑΝΔΡΟΣ Δ.',
#   'Ημερομηνία εξαφάνισης : 19 Νοεμβρίου 2021',
#   'Ημερομηνία Γέννησης : 15 Ιανουαρίου 2008',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΜΙΧΑΗΛ Γ.',
#   'Ημερομηνία εξαφάνισης : 17 Νοεμβρίου 2021',
#   'Ημερομηνία Γέννησης : 08 Απριλίου 2006',
#   'Χρώμα Ματιών : ΜΠΛΕ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : ΣΑΛΗ Σ.',
#   'Ημερομηνία εξαφάνισης : 14 Νοεμβρίου 2021',
#   'Ημερομηνία Γέννησης : 10 Μαρτίου 2007',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΟΚΚΙΝΑ'],
#  ['Όνομα : ΣΤΑΜΑΤΙΝΑ Σ.',
#   'Ημερομηνία εξαφάνισης : 15 Οκτωβρίου 2021',
#   'Ημερομηνία Γέννησης : 01 Νοεμβρίου 2005',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΣΑΧΑΜΠ ΖΑΝΤΑ ΜΠΙΜΠΙ ΑΜΙΝΑ',
#   'Ημερομηνία εξαφάνισης : 25 Σεπτεμβρίου 2021',
#   'Ημερομηνία Γέννησης : 28 Απριλίου 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΜΙΑ ΜΑΡΙΑΜ',
#   'Ημερομηνία εξαφάνισης : 02 Μαίου 2021',
#   'Ημερομηνία Γέννησης : 13 Αυγούστου 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΙΖΑΜΠΕΛΑ-ΕΛΕΝΑ (ον.) Σ.(επ.)',
#   'Ημερομηνία εξαφάνισης : 15 Οκτωβρίου 2020',
#   'Ημερομηνία Γέννησης : 30 June 2006',
#   'Χρώμα Ματιών : ΜΑΥΡΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : ΡΑΦΑΗΛΙΑ Ε.',
#   'Ημερομηνία εξαφάνισης : 24 Αυγούστου 2020',
#   'Ημερομηνία Γέννησης : 13 Φεβρουαρίου 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΜΠΕΡΧΟ(επ.) ΑΧΜΑΝΤ(ον.)',
#   'Ημερομηνία εξαφάνισης : 20 June 2020',
#   'Ημερομηνία Γέννησης : 01 Σεπτεμβρίου 2015',
#   'Χρώμα Ματιών : ',
#   'Χρώμα Μαλλιών : '],
#  ['Όνομα : ΝΙΑΖΙ (ΕΠΩΝΥΜΟ) ΣΑΜΙΡ(ΟΝΟΜΑ)',
#   'Ημερομηνία εξαφάνισης : 23 Δεκεμβρίου 2019',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2007',
#   'Χρώμα Ματιών : ΜΑΥΡΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : BAHROUZ(ον.) KHOSHNAW (επ.)',
#   'Ημερομηνία εξαφάνισης : 09 Δεκεμβρίου 2019',
#   'Ημερομηνία Γέννησης : 02 Απριλίου 2007',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : ΣΑΦΝΤΑΡ ΑΧΜΑΝΤΙ',
#   'Ημερομηνία εξαφάνισης : 18 Αυγούστου 2019',
#   'Ημερομηνία Γέννησης : 21 Μαρτίου 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : HASHEMI SHOKROLLAH',
#   'Ημερομηνία εξαφάνισης : 05 Αυγούστου 2019',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2003',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΒΑΜΜΕΝΑ ΚΟΚΚΙΝΑ'],
#  ['Όνομα : ΜΟΧΙΣΑ ΧΟΡΜΑΤ',
#   'Ημερομηνία εξαφάνισης : 02 Ιουλίου 2019',
#   'Ημερομηνία Γέννησης : 21 Ιανουαρίου 2003',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ'],
#  ['Όνομα : ΜΟΥΚΤΑΡ ΤΑΜΠΙΣ',
#   'Ημερομηνία εξαφάνισης : 20 Απριλίου 2019',
#   'Ημερομηνία Γέννησης : 13 Φεβρουαρίου 2004',
#   'Χρώμα Ματιών : ΜΑΥΡΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : ΑΝΕΛΙΑ Ν.',
#   'Ημερομηνία εξαφάνισης : 10 Απριλίου 2019',
#   'Ημερομηνία Γέννησης : 17 Νοεμβρίου 2004',
#   'Χρώμα Ματιών : ΜΑΥΡΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : ΑΧΜΕΝΤ ΝΑΣΤΕΧΑ',
#   'Ημερομηνία εξαφάνισης : 03 Φεβρουαρίου 2019',
#   'Ημερομηνία Γέννησης : 02 Φεβρουαρίου 2003',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ'],
#  ['Όνομα : ΓΙΟΥΣΕΦ ΟΣΣΟ',
#   'Ημερομηνία εξαφάνισης : 03 Ιουλίου 2018',
#   'Ημερομηνία Γέννησης : 19 Ιουλίου 2006',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΧΛΟΥΝΤ ΑΪΟΜΠΑΪΝΤΙ',
#   'Ημερομηνία εξαφάνισης : 21 Μαίου 2018',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2003',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΜΑΥΡΑ'],
#  ['Όνομα : AYA MOHAMMED OLEIWI ',
#   'Ημερομηνία εξαφάνισης : 01 Νοεμβρίου 2016',
#   'Ημερομηνία Γέννησης : 23 June 2006',
#   'Χρώμα Ματιών : ΚΑΣΤΑΝΑ',
#   'Χρώμα Μαλλιών : ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ'],
#  ['Όνομα : ΤΡΑΪΑΝ-ΝΤΑΤΣΙΟΥ Κ.',
#   'Ημερομηνία εξαφάνισης : 14 Απριλίου 2016',
#   'Ημερομηνία Γέννησης : 02 Φεβρουαρίου 2003',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΝΑΣΤΑΡΑΝ ΧΕΪΝΤΑΡΙ',
#   'Ημερομηνία εξαφάνισης : 22 Ιανουαρίου 2016',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2009',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΑΜΙΡ ΓΙΑΣΙΜ ΣΑΜΟ',
#   'Ημερομηνία εξαφάνισης : 10 Δεκεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 11 Φεβρουαρίου 2003',
#   'Χρώμα Ματιών : Καφέ',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΡΟΝΤΕΡ ΟΘΜΑΝ',
#   'Ημερομηνία εξαφάνισης : 11 Νοεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 10 Φεβρουαρίου 2011',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΑΛΝΤ ΟΘΜΑΝ',
#   'Ημερομηνία εξαφάνισης : 11 Νοεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 03 Ιανουαρίου 2010',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΡΟΝΤΙ ΤΖΑΜΙΛ',
#   'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#   'Ημερομηνία Γέννησης : 05 Ιουλίου 2005',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΣΟΛΙΝ ΤΖΑΜΙΛ',
#   'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#   'Ημερομηνία Γέννησης : 01 Νοεμβρίου 2007',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΡΟΝΙ ΤΖΑΜΙΛ',
#   'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#   'Ημερομηνία Γέννησης : 15 Ιανουαρίου 2009',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΜΑΣΣΟΥΝ ΤΖΑΜΙΛ',
#   'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#   'Ημερομηνία Γέννησης : 09 Σεπτεμβρίου 2009',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΜΟΧΑΜΑΝΤ ΤΖΑΜΙΛ',
#   'Ημερομηνία εξαφάνισης : 21 Οκτωβρίου 2015',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2011',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα : ΜΟΧΑΜΕΤ και ΑΜΠΑΣ ΑΛΚΑΦΑΝΤΖΙ',
#   'Ημερομηνία εξαφάνισης : 13 Σεπτεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 10 Σεπτεμβρίου 2010',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΑΓΙΑ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 01 Απριλίου 2002',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΣΑΓΙΑΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 05 Νοεμβρίου 2007',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΑΧΜΕΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   'Ημερομηνία εξαφάνισης : 11 Σεπτεμβρίου 2015',
#   'Ημερομηνία Γέννησης : 20 Απριλίου 2004',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΟΛΙΒΙΑ ΕΝΘΙΝΑΣ ΧΛΟΝΤ',
#   'Ημερομηνία εξαφάνισης : 31 Δεκεμβρίου 2011',
#   'Ημερομηνία Γέννησης : 25 Απριλίου 2008',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : LEONG JIN KUOK',
#   'Ημερομηνία εξαφάνισης : 27 Σεπτεμβρίου 2011',
#   'Ημερομηνία Γέννησης : 22 Αυγούστου 1983',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : BENEDETTA BIENAIME',
#   'Ημερομηνία εξαφάνισης : 15 Απριλίου 2011',
#   'Ημερομηνία Γέννησης : 30 Οκτωβρίου 2006',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ALESSIA SCHEPP',
#   'Ημερομηνία εξαφάνισης : 30 Ιανουαρίου 2011',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2005',
#   'Χρώμα Ματιών : Πράσινα',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα : LIVIA SCHEPP',
#   'Ημερομηνία εξαφάνισης : 30 Ιανουαρίου 2011',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 2005',
#   'Χρώμα Ματιών : Μπλε',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα : SAMEEM FAZLI',
#   'Ημερομηνία εξαφάνισης : 14 Ιουλίου 2009',
#   'Ημερομηνία Γέννησης : 24 Δεκεμβρίου 2000',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : MATEO DULLIA',
#   'Ημερομηνία εξαφάνισης : 07 Σεπτεμβρίου 2008',
#   'Ημερομηνία Γέννησης : 28 Σεπτεμβρίου 2007',
#   'Χρώμα Ματιών : Γκριζοπράσινα',
#   'Χρώμα Μαλλιών : Καστανά ανοιχτά'],
#  ['Όνομα : ANDREA LIPONI',
#   'Ημερομηνία εξαφάνισης : 31 Μαίου 2008',
#   'Ημερομηνία Γέννησης : 02 Αυγούστου 1986',
#   'Χρώμα Ματιών : -',
#   'Χρώμα Μαλλιών : -'],
#  ['Όνομα : ZAHRA MOSA',
#   'Ημερομηνία εξαφάνισης : 16 Φεβρουαρίου 2008',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 1994',
#   'Χρώμα Ματιών : Μαύρα',
#   'Χρώμα Μαλλιών : Μαύρα'],
#  ['Όνομα : ΧΑΛΙΛ ΑΛΕΙΣΑ',
#   'Ημερομηνία εξαφάνισης : 22 June 2007',
#   'Ημερομηνία Γέννησης : 05 Ιανουαρίου 1990',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : MADELEINE McCANN',
#   'Ημερομηνία εξαφάνισης : 03 Μαίου 2007',
#   'Ημερομηνία Γέννησης : 12 Μαίου 2003',
#   'Χρώμα Ματιών : Πράσινα',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα : SIMON ANDREEA',
#   'Ημερομηνία εξαφάνισης : 15 Δεκεμβρίου 2005',
#   'Ημερομηνία Γέννησης : 01 Ιανουαρίου 1996',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΝΤΕΝΙΣ ΠΙΠΙΤΟΝ',
#   'Ημερομηνία εξαφάνισης : 01 Σεπτεμβρίου 2004',
#   'Ημερομηνία Γέννησης : 26 Οκτωβρίου 2000',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΑΡΤΟΥΡ ΤΣΑΡΙΑ',
#   'Ημερομηνία εξαφάνισης : 09 Ιουλίου 2004',
#   'Ημερομηνία Γέννησης : 12 Αυγούστου 1995',
#   'Χρώμα Ματιών : Καφέ σκούρα',
#   'Χρώμα Μαλλιών : Καστανά'],
#  ['Όνομα : ΘΕΜΙΣΤΟΚΛΗΣ ΕΥΘΥΜΙΑΔΗΣ',
#   'Ημερομηνία εξαφάνισης : 30 June 2000',
#   'Ημερομηνία Γέννησης : 28 Οκτωβρίου 1984',
#   'Χρώμα Ματιών : Γαλάζια',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα :  ΓΕΩΡΓΙΟΣ ΠΑΡΑΣΚΕΥΟΠΟΥΛΟΣ',
#   'Ημερομηνία εξαφάνισης : 24 June 1992',
#   'Ημερομηνία Γέννησης : 05 Μαρτίου 1982',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανόξανθα'],
#  ['Όνομα : BEN NEEDHAM',
#   'Ημερομηνία εξαφάνισης : 24 Ιουλίου 1991',
#   'Ημερομηνία Γέννησης : 29 Οκτωβρίου 1989',
#   'Χρώμα Ματιών : Γαλανά',
#   'Χρώμα Μαλλιών : Ξανθά'],
#  ['Όνομα : ΑΝΝΑ ΤΡΙΑΝΤΑΦΥΛΛΙΔΟΥ',
#   'Ημερομηνία εξαφάνισης : 19 Αυγούστου 1981',
#   'Ημερομηνία Γέννησης : 26 June 1979',
#   'Χρώμα Ματιών : Καστανά',
#   'Χρώμα Μαλλιών : Καστανά']]

# %%
#επιβεβαιώνω ότι είναι ίδιος ο αριθμός με τα url, άρα χωρίστηκαν σωστά
print(len(z))
# Out:
# 55

# %% [markdown]
# Τώρα θέλω να τα μετατρέψω σε df αλλά πρέπει να βγάλω το "όνομα : ", "ημερομηνία εξαφάνισης : " κτλ. από κάθε εγγραφή- λίστα δεδομένων ανα παιδι.

# %%
import re

# %%
z = [[re.sub(r".*\s.*" + ': ' , r'', item) for item in sub_list] for sub_list in z]
z
# Out:
# [['ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.',
#   '21 Ιανουαρίου 2022',
#   '02 Οκτωβρίου 2008',
#   'ΚΑΣΤΑΝΑ',
#   'ΜΑΥΡΑ ΚΟΝΤΑ '],
#  ['ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ',
#   '13 Ιανουαρίου 2022',
#   '28 Απριλίου 2006',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΧΙΤΖΑΖΙ ΑΘΗΝΑ',
#   '21 Νοεμβρίου 2021',
#   '23 Φεβρουαρίου 2017',
#   'ΚΑΣΤΑΝΑ',
#   'ΜΑΥΡΑ ΜΑΚΡΙΑ'],
#  ['ΑΛΕΞΑΝΔΡΟΣ Δ.',
#   '19 Νοεμβρίου 2021',
#   '15 Ιανουαρίου 2008',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΜΙΧΑΗΛ Γ.', '17 Νοεμβρίου 2021', '08 Απριλίου 2006', 'ΜΠΛΕ', 'ΜΑΥΡΑ'],
#  ['ΣΑΛΗ Σ.', '14 Νοεμβρίου 2021', '10 Μαρτίου 2007', 'ΚΑΣΤΑΝΑ', 'ΚΟΚΚΙΝΑ'],
#  ['ΣΤΑΜΑΤΙΝΑ Σ.',
#   '15 Οκτωβρίου 2021',
#   '01 Νοεμβρίου 2005',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΣΑΧΑΜΠ ΖΑΝΤΑ ΜΠΙΜΠΙ ΑΜΙΝΑ',
#   '25 Σεπτεμβρίου 2021',
#   '28 Απριλίου 2006',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΜΙΑ ΜΑΡΙΑΜ', '02 Μαίου 2021', '13 Αυγούστου 2006', 'ΚΑΣΤΑΝΑ', 'ΚΑΣΤΑΝΑ'],
#  ['ΙΖΑΜΠΕΛΑ-ΕΛΕΝΑ (ον.) Σ.(επ.)',
#   '15 Οκτωβρίου 2020',
#   '30 June 2006',
#   'ΜΑΥΡΑ',
#   'ΜΑΥΡΑ'],
#  ['ΡΑΦΑΗΛΙΑ Ε.',
#   '24 Αυγούστου 2020',
#   '13 Φεβρουαρίου 2006',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΜΠΕΡΧΟ(επ.) ΑΧΜΑΝΤ(ον.)', '20 June 2020', '01 Σεπτεμβρίου 2015', '', ''],
#  ['ΝΙΑΖΙ (ΕΠΩΝΥΜΟ) ΣΑΜΙΡ(ΟΝΟΜΑ)',
#   '23 Δεκεμβρίου 2019',
#   '01 Ιανουαρίου 2007',
#   'ΜΑΥΡΑ',
#   'ΜΑΥΡΑ'],
#  ['BAHROUZ(ον.) KHOSHNAW (επ.)',
#   '09 Δεκεμβρίου 2019',
#   '02 Απριλίου 2007',
#   'ΚΑΣΤΑΝΑ',
#   'ΜΑΥΡΑ'],
#  ['ΣΑΦΝΤΑΡ ΑΧΜΑΝΤΙ',
#   '18 Αυγούστου 2019',
#   '21 Μαρτίου 2006',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['HASHEMI SHOKROLLAH',
#   '05 Αυγούστου 2019',
#   '01 Ιανουαρίου 2003',
#   'ΚΑΣΤΑΝΑ',
#   'ΒΑΜΜΕΝΑ ΚΟΚΚΙΝΑ'],
#  ['ΜΟΧΙΣΑ ΧΟΡΜΑΤ',
#   '02 Ιουλίου 2019',
#   '21 Ιανουαρίου 2003',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ'],
#  ['ΜΟΥΚΤΑΡ ΤΑΜΠΙΣ',
#   '20 Απριλίου 2019',
#   '13 Φεβρουαρίου 2004',
#   'ΜΑΥΡΑ',
#   'ΜΑΥΡΑ'],
#  ['ΑΝΕΛΙΑ Ν.', '10 Απριλίου 2019', '17 Νοεμβρίου 2004', 'ΜΑΥΡΑ', 'ΜΑΥΡΑ'],
#  ['ΑΧΜΕΝΤ ΝΑΣΤΕΧΑ',
#   '03 Φεβρουαρίου 2019',
#   '02 Φεβρουαρίου 2003',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ'],
#  ['ΓΙΟΥΣΕΦ ΟΣΣΟ', '03 Ιουλίου 2018', '19 Ιουλίου 2006', 'Μαύρα', 'Καστανά'],
#  ['ΧΛΟΥΝΤ ΑΪΟΜΠΑΪΝΤΙ',
#   '21 Μαίου 2018',
#   '01 Ιανουαρίου 2003',
#   'ΚΑΣΤΑΝΑ',
#   'ΜΑΥΡΑ'],
#  ['AYA MOHAMMED OLEIWI ',
#   '01 Νοεμβρίου 2016',
#   '23 June 2006',
#   'ΚΑΣΤΑΝΑ',
#   'ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ'],
#  ['ΤΡΑΪΑΝ-ΝΤΑΤΣΙΟΥ Κ.',
#   '14 Απριλίου 2016',
#   '02 Φεβρουαρίου 2003',
#   'Καστανά',
#   'Καστανά'],
#  ['ΝΑΣΤΑΡΑΝ ΧΕΪΝΤΑΡΙ',
#   '22 Ιανουαρίου 2016',
#   '01 Ιανουαρίου 2009',
#   'Καστανά',
#   'Μαύρα'],
#  ['ΑΜΙΡ ΓΙΑΣΙΜ ΣΑΜΟ',
#   '10 Δεκεμβρίου 2015',
#   '11 Φεβρουαρίου 2003',
#   'Καφέ',
#   'Μαύρα'],
#  ['ΡΟΝΤΕΡ ΟΘΜΑΝ',
#   '11 Νοεμβρίου 2015',
#   '10 Φεβρουαρίου 2011',
#   'Καστανά',
#   'Καστανά'],
#  ['ΑΛΝΤ ΟΘΜΑΝ', '11 Νοεμβρίου 2015', '03 Ιανουαρίου 2010', 'Μαύρα', 'Μαύρα'],
#  ['ΡΟΝΤΙ ΤΖΑΜΙΛ', '21 Οκτωβρίου 2015', '05 Ιουλίου 2005', 'Μαύρα', 'Μαύρα'],
#  ['ΣΟΛΙΝ ΤΖΑΜΙΛ',
#   '21 Οκτωβρίου 2015',
#   '01 Νοεμβρίου 2007',
#   'Καστανά',
#   'Καστανά'],
#  ['ΡΟΝΙ ΤΖΑΜΙΛ', '21 Οκτωβρίου 2015', '15 Ιανουαρίου 2009', 'Μαύρα', 'Μαύρα'],
#  ['ΜΑΣΣΟΥΝ ΤΖΑΜΙΛ',
#   '21 Οκτωβρίου 2015',
#   '09 Σεπτεμβρίου 2009',
#   'Καστανά',
#   'Μαύρα'],
#  ['ΜΟΧΑΜΑΝΤ ΤΖΑΜΙΛ',
#   '21 Οκτωβρίου 2015',
#   '01 Ιανουαρίου 2011',
#   'Μαύρα',
#   'Ξανθά'],
#  ['ΜΟΧΑΜΕΤ και ΑΜΠΑΣ ΑΛΚΑΦΑΝΤΖΙ',
#   '13 Σεπτεμβρίου 2015',
#   '10 Σεπτεμβρίου 2010',
#   'Μαύρα',
#   'Μαύρα'],
#  ['ΑΓΙΑ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   '11 Σεπτεμβρίου 2015',
#   '01 Απριλίου 2002',
#   'Μαύρα',
#   'Μαύρα'],
#  ['ΣΑΓΙΑΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   '11 Σεπτεμβρίου 2015',
#   '05 Νοεμβρίου 2007',
#   'Μαύρα',
#   'Μαύρα'],
#  ['ΑΧΜΕΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ',
#   '11 Σεπτεμβρίου 2015',
#   '20 Απριλίου 2004',
#   'Μαύρα',
#   'Μαύρα'],
#  ['ΟΛΙΒΙΑ ΕΝΘΙΝΑΣ ΧΛΟΝΤ',
#   '31 Δεκεμβρίου 2011',
#   '25 Απριλίου 2008',
#   'Καστανά',
#   'Καστανά'],
#  ['LEONG JIN KUOK',
#   '27 Σεπτεμβρίου 2011',
#   '22 Αυγούστου 1983',
#   'Μαύρα',
#   'Μαύρα'],
#  ['BENEDETTA BIENAIME',
#   '15 Απριλίου 2011',
#   '30 Οκτωβρίου 2006',
#   'Καστανά',
#   'Καστανά'],
#  ['ALESSIA SCHEPP',
#   '30 Ιανουαρίου 2011',
#   '01 Ιανουαρίου 2005',
#   'Πράσινα',
#   'Ξανθά'],
#  ['LIVIA SCHEPP', '30 Ιανουαρίου 2011', '01 Ιανουαρίου 2005', 'Μπλε', 'Ξανθά'],
#  ['SAMEEM FAZLI', '14 Ιουλίου 2009', '24 Δεκεμβρίου 2000', 'Μαύρα', 'Μαύρα'],
#  ['MATEO DULLIA',
#   '07 Σεπτεμβρίου 2008',
#   '28 Σεπτεμβρίου 2007',
#   'Γκριζοπράσινα',
#   'Καστανά ανοιχτά'],
#  ['ANDREA LIPONI', '31 Μαίου 2008', '02 Αυγούστου 1986', '-', '-'],
#  ['ZAHRA MOSA', '16 Φεβρουαρίου 2008', '01 Ιανουαρίου 1994', 'Μαύρα', 'Μαύρα'],
#  ['ΧΑΛΙΛ ΑΛΕΙΣΑ', '22 June 2007', '05 Ιανουαρίου 1990', 'Καστανά', 'Καστανά'],
#  ['MADELEINE McCANN', '03 Μαίου 2007', '12 Μαίου 2003', 'Πράσινα', 'Ξανθά'],
#  ['SIMON ANDREEA',
#   '15 Δεκεμβρίου 2005',
#   '01 Ιανουαρίου 1996',
#   'Καστανά',
#   'Καστανά'],
#  ['ΝΤΕΝΙΣ ΠΙΠΙΤΟΝ',
#   '01 Σεπτεμβρίου 2004',
#   '26 Οκτωβρίου 2000',
#   'Καστανά',
#   'Καστανά'],
#  ['ΑΡΤΟΥΡ ΤΣΑΡΙΑ',
#   '09 Ιουλίου 2004',
#   '12 Αυγούστου 1995',
#   'Καφέ σκούρα',
#   'Καστανά'],
#  ['ΘΕΜΙΣΤΟΚΛΗΣ ΕΥΘΥΜΙΑΔΗΣ',
#   '30 June 2000',
#   '28 Οκτωβρίου 1984',
#   'Γαλάζια',
#   'Ξανθά'],
#  [' ΓΕΩΡΓΙΟΣ ΠΑΡΑΣΚΕΥΟΠΟΥΛΟΣ',
#   '24 June 1992',
#   '05 Μαρτίου 1982',
#   'Καστανά',
#   'Καστανόξανθα'],
#  ['BEN NEEDHAM', '24 Ιουλίου 1991', '29 Οκτωβρίου 1989', 'Γαλανά', 'Ξανθά'],
#  ['ΑΝΝΑ ΤΡΙΑΝΤΑΦΥΛΛΙΔΟΥ',
#   '19 Αυγούστου 1981',
#   '26 June 1979',
#   'Καστανά',
#   'Καστανά']]

# %% [markdown]
# ##3. Μετατρέπω τα δεδομένα μου σε df

# %%
columns = ['Name','Date Missing','Birthdate','Eyes', 'Hair']
df = pd.DataFrame(z, columns=columns)
df.head(6)
# Out:
#                         Name        Date Missing            Birthdate  \
# 0          ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.  21 Ιανουαρίου 2022    02 Οκτωβρίου 2008
# 1  ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ  13 Ιανουαρίου 2022     28 Απριλίου 2006
# 2              ΧΙΤΖΑΖΙ ΑΘΗΝΑ   21 Νοεμβρίου 2021  23 Φεβρουαρίου 2017
# 3              ΑΛΕΞΑΝΔΡΟΣ Δ.   19 Νοεμβρίου 2021   15 Ιανουαρίου 2008
# 4                  ΜΙΧΑΗΛ Γ.   17 Νοεμβρίου 2021     08 Απριλίου 2006
# 5                    ΣΑΛΗ Σ.   14 Νοεμβρίου 2021      10 Μαρτίου 2007
#
#       Eyes          Hair
# 0  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΚΟΝΤΑ
# 1  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 2  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΜΑΚΡΙΑ
# 3  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 4     ΜΠΛΕ         ΜΑΥΡΑ
# 5  ΚΑΣΤΑΝΑ       ΚΟΚΚΙΝΑ

# %%
#προσθέτω στο df και μια στήλη με τα urls από την λίστα child_url που ειχα φτιάξει στην αρχή
df['Info Url'] = child_url
df.tail()
# Out:
#                          Name       Date Missing          Birthdate  \
# 50              ΑΡΤΟΥΡ ΤΣΑΡΙΑ    09 Ιουλίου 2004  12 Αυγούστου 1995
# 51     ΘΕΜΙΣΤΟΚΛΗΣ ΕΥΘΥΜΙΑΔΗΣ       30 June 2000  28 Οκτωβρίου 1984
# 52   ΓΕΩΡΓΙΟΣ ΠΑΡΑΣΚΕΥΟΠΟΥΛΟΣ       24 June 1992    05 Μαρτίου 1982
# 53                BEN NEEDHAM    24 Ιουλίου 1991  29 Οκτωβρίου 1989
# 54       ΑΝΝΑ ΤΡΙΑΝΤΑΦΥΛΛΙΔΟΥ  19 Αυγούστου 1981       26 June 1979
#
#            Eyes          Hair  \
# 50  Καφέ σκούρα       Καστανά
# 51      Γαλάζια         Ξανθά
# 52      Καστανά  Καστανόξανθα
# 53       Γαλανά         Ξανθά
# 54      Καστανά       Καστανά
#
#                                              Info Url
# 50  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 51  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 52  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 53  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 54  https://www.hamogelo.gr/gr/el/ajax/missingchil...

# %% [markdown]
# ##4. Επεξεργάζομαι το df
#
# Πρωτού αποθηκεύσω το df σε csv, θα φτιάξω νέα στήλη που θα υπολογίζει ηλικία παιδιού όταν εξαφανίστηκε... Γι αυτό χρειάζεται να φτιάξω τις στήλες με τις ημερομηνίες

# %%
from datetime import datetime

# %%
#Φτιάχνω ένα λεξικό αγγλικών-ελληνικών μηνών για να μετατρέψω τους μήνες μου σε αριθμό.
d = {'Σεπτεμβρίου': '09', 'Οκτωβρίου': '10', 'Νοεμβρίου': '11', 'Δεκεμβρίου': '12', 'Ιανουαρίου': '01', 'Φεβρουαρίου': '02', 'Μαρτίου': '03', 'Απριλίου': '04', 'Μαίου': '05', 'Ιουνίου': '06', 'Ιουλίου': '07', 'Αυγούστου': '08', 'September': '09', 'Octomber': '10', 'November': '11', 'December': '12', 'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05', 'June': '06', 'July': '07', 'August': '08'}

df['Date Missing'] = df['Date Missing'].replace(d, regex=True)
df['Date Missing'] = pd.to_datetime(df['Date Missing'], format='%d %m %Y')

df['Birthdate'] = df['Birthdate'].replace(d, regex=True)
df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%d %m %Y', errors='coerce')

# %%
df
# Out:
#                                     Name Date Missing  Birthdate  \
# 0                      ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.   2022-01-21 2008-10-02
# 1              ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ   2022-01-13 2006-04-28
# 2                          ΧΙΤΖΑΖΙ ΑΘΗΝΑ   2021-11-21 2017-02-23
# 3                          ΑΛΕΞΑΝΔΡΟΣ Δ.   2021-11-19 2008-01-15
# 4                              ΜΙΧΑΗΛ Γ.   2021-11-17 2006-04-08
# 5                                ΣΑΛΗ Σ.   2021-11-14 2007-03-10
# 6                           ΣΤΑΜΑΤΙΝΑ Σ.   2021-10-15 2005-11-01
# 7              ΣΑΧΑΜΠ ΖΑΝΤΑ ΜΠΙΜΠΙ ΑΜΙΝΑ   2021-09-25 2006-04-28
# 8                             ΜΙΑ ΜΑΡΙΑΜ   2021-05-02 2006-08-13
# 9           ΙΖΑΜΠΕΛΑ-ΕΛΕΝΑ (ον.) Σ.(επ.)   2020-10-15 2006-06-30
# 10                           ΡΑΦΑΗΛΙΑ Ε.   2020-08-24 2006-02-13
# 11               ΜΠΕΡΧΟ(επ.) ΑΧΜΑΝΤ(ον.)   2020-06-20 2015-09-01
# 12          ΝΙΑΖΙ (ΕΠΩΝΥΜΟ) ΣΑΜΙΡ(ΟΝΟΜΑ)   2019-12-23 2007-01-01
# 13           BAHROUZ(ον.) KHOSHNAW (επ.)   2019-12-09 2007-04-02
# 14                       ΣΑΦΝΤΑΡ ΑΧΜΑΝΤΙ   2019-08-18 2006-03-21
# 15                    HASHEMI SHOKROLLAH   2019-08-05 2003-01-01
# 16                         ΜΟΧΙΣΑ ΧΟΡΜΑΤ   2019-07-02 2003-01-21
# 17                        ΜΟΥΚΤΑΡ ΤΑΜΠΙΣ   2019-04-20 2004-02-13
# 18                             ΑΝΕΛΙΑ Ν.   2019-04-10 2004-11-17
# 19                        ΑΧΜΕΝΤ ΝΑΣΤΕΧΑ   2019-02-03 2003-02-02
# 20                          ΓΙΟΥΣΕΦ ΟΣΣΟ   2018-07-03 2006-07-19
# 21                     ΧΛΟΥΝΤ ΑΪΟΜΠΑΪΝΤΙ   2018-05-21 2003-01-01
# 22                  AYA MOHAMMED OLEIWI    2016-11-01 2006-06-23
# 23                    ΤΡΑΪΑΝ-ΝΤΑΤΣΙΟΥ Κ.   2016-04-14 2003-02-02
# 24                     ΝΑΣΤΑΡΑΝ ΧΕΪΝΤΑΡΙ   2016-01-22 2009-01-01
# 25                      ΑΜΙΡ ΓΙΑΣΙΜ ΣΑΜΟ   2015-12-10 2003-02-11
# 26                          ΡΟΝΤΕΡ ΟΘΜΑΝ   2015-11-11 2011-02-10
# 27                            ΑΛΝΤ ΟΘΜΑΝ   2015-11-11 2010-01-03
# 28                          ΡΟΝΤΙ ΤΖΑΜΙΛ   2015-10-21 2005-07-05
# 29                          ΣΟΛΙΝ ΤΖΑΜΙΛ   2015-10-21 2007-11-01
# 30                           ΡΟΝΙ ΤΖΑΜΙΛ   2015-10-21 2009-01-15
# 31                        ΜΑΣΣΟΥΝ ΤΖΑΜΙΛ   2015-10-21 2009-09-09
# 32                       ΜΟΧΑΜΑΝΤ ΤΖΑΜΙΛ   2015-10-21 2011-01-01
# 33          ΜΟΧΑΜΕΤ και ΑΜΠΑΣ ΑΛΚΑΦΑΝΤΖΙ   2015-09-13 2010-09-10
# 34     ΑΓΙΑ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ   2015-09-11 2002-04-01
# 35  ΣΑΓΙΑΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ   2015-09-11 2007-11-05
# 36   ΑΧΜΕΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ   2015-09-11 2004-04-20
# 37                  ΟΛΙΒΙΑ ΕΝΘΙΝΑΣ ΧΛΟΝΤ   2011-12-31 2008-04-25
# 38                        LEONG JIN KUOK   2011-09-27 1983-08-22
# 39                    BENEDETTA BIENAIME   2011-04-15 2006-10-30
# 40                        ALESSIA SCHEPP   2011-01-30 2005-01-01
# 41                          LIVIA SCHEPP   2011-01-30 2005-01-01
# 42                          SAMEEM FAZLI   2009-07-14 2000-12-24
# 43                          MATEO DULLIA   2008-09-07 2007-09-28
# 44                         ANDREA LIPONI   2008-05-31 1986-08-02
# 45                            ZAHRA MOSA   2008-02-16 1994-01-01
# 46                          ΧΑΛΙΛ ΑΛΕΙΣΑ   2007-06-22 1990-01-05
# 47                      MADELEINE McCANN   2007-05-03 2003-05-12
# 48                         SIMON ANDREEA   2005-12-15 1996-01-01
# 49                        ΝΤΕΝΙΣ ΠΙΠΙΤΟΝ   2004-09-01 2000-10-26
# 50                         ΑΡΤΟΥΡ ΤΣΑΡΙΑ   2004-07-09 1995-08-12
# 51                ΘΕΜΙΣΤΟΚΛΗΣ ΕΥΘΥΜΙΑΔΗΣ   2000-06-30 1984-10-28
# 52              ΓΕΩΡΓΙΟΣ ΠΑΡΑΣΚΕΥΟΠΟΥΛΟΣ   1992-06-24 1982-03-05
# 53                           BEN NEEDHAM   1991-07-24 1989-10-29
# 54                  ΑΝΝΑ ΤΡΙΑΝΤΑΦΥΛΛΙΔΟΥ   1981-08-19 1979-06-26
#
#              Eyes             Hair  \
# 0         ΚΑΣΤΑΝΑ     ΜΑΥΡΑ ΚΟΝΤΑ
# 1         ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 2         ΚΑΣΤΑΝΑ     ΜΑΥΡΑ ΜΑΚΡΙΑ
# 3         ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 4            ΜΠΛΕ            ΜΑΥΡΑ
# 5         ΚΑΣΤΑΝΑ          ΚΟΚΚΙΝΑ
# 6         ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 7         ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 8         ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 9           ΜΑΥΡΑ            ΜΑΥΡΑ
# 10        ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 11
# 12          ΜΑΥΡΑ            ΜΑΥΡΑ
# 13        ΚΑΣΤΑΝΑ            ΜΑΥΡΑ
# 14        ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 15        ΚΑΣΤΑΝΑ  ΒΑΜΜΕΝΑ ΚΟΚΚΙΝΑ
# 16        ΚΑΣΤΑΝΑ   ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ
# 17          ΜΑΥΡΑ            ΜΑΥΡΑ
# 18          ΜΑΥΡΑ            ΜΑΥΡΑ
# 19        ΚΑΣΤΑΝΑ          ΚΑΣΤΑΝΑ
# 20          Μαύρα          Καστανά
# 21        ΚΑΣΤΑΝΑ            ΜΑΥΡΑ
# 22        ΚΑΣΤΑΝΑ   ΚΑΣΤΑΝΑ ΜΑΚΡΙΑ
# 23        Καστανά          Καστανά
# 24        Καστανά            Μαύρα
# 25           Καφέ            Μαύρα
# 26        Καστανά          Καστανά
# 27          Μαύρα            Μαύρα
# 28          Μαύρα            Μαύρα
# 29        Καστανά          Καστανά
# 30          Μαύρα            Μαύρα
# 31        Καστανά            Μαύρα
# 32          Μαύρα            Ξανθά
# 33          Μαύρα            Μαύρα
# 34          Μαύρα            Μαύρα
# 35          Μαύρα            Μαύρα
# 36          Μαύρα            Μαύρα
# 37        Καστανά          Καστανά
# 38          Μαύρα            Μαύρα
# 39        Καστανά          Καστανά
# 40        Πράσινα            Ξανθά
# 41           Μπλε            Ξανθά
# 42          Μαύρα            Μαύρα
# 43  Γκριζοπράσινα  Καστανά ανοιχτά
# 44              -                -
# 45          Μαύρα            Μαύρα
# 46        Καστανά          Καστανά
# 47        Πράσινα            Ξανθά
# 48        Καστανά          Καστανά
# 49        Καστανά          Καστανά
# 50    Καφέ σκούρα          Καστανά
# 51        Γαλάζια            Ξανθά
# 52        Καστανά     Καστανόξανθα
# 53         Γαλανά            Ξανθά
# 54        Καστανά          Καστανά
#
#                                              Info Url
# 0   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 1   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 2   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 3   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 4   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 5   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 6   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 7   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 8   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 9   https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 10  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 11  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 12  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 13  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 14  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 15  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 16  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 17  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 18  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 19  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 20  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 21  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 22  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 23  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 24  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 25  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 26  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 27  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 28  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 29  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 30  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 31  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 32  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 33  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 34  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 35  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 36  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 37  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 38  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 39  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 40  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 41  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 42  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 43  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 44  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 45  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 46  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 47  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 48  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 49  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 50  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 51  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 52  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 53  https://www.hamogelo.gr/gr/el/ajax/missingchil...
# 54  https://www.hamogelo.gr/gr/el/ajax/missingchil...

# %%
df.dtypes
# Out:
# Name                    object
# Date Missing    datetime64[ns]
# Birthdate       datetime64[ns]
# Eyes                    object
# Hair                    object
# Info Url                object
# dtype: object

# %%
#astype('<m8[Y]') βαζω αυτό γιατι διαφορετικά υπολογίζει ημέρες και εγω θέλω χρόνια στην ηλικία
df['Age']= (df['Date Missing']- df['Birthdate']).astype('<m8[Y]')
df.head()
# Out:
#                         Name Date Missing  Birthdate     Eyes          Hair  \
# 0          ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.   2022-01-21 2008-10-02  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΚΟΝΤΑ
# 1  ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ   2022-01-13 2006-04-28  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 2              ΧΙΤΖΑΖΙ ΑΘΗΝΑ   2021-11-21 2017-02-23  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΜΑΚΡΙΑ
# 3              ΑΛΕΞΑΝΔΡΟΣ Δ.   2021-11-19 2008-01-15  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 4                  ΜΙΧΑΗΛ Γ.   2021-11-17 2006-04-08     ΜΠΛΕ         ΜΑΥΡΑ
#
#                                             Info Url   Age
# 0  https://www.hamogelo.gr/gr/el/ajax/missingchil...  13.0
# 1  https://www.hamogelo.gr/gr/el/ajax/missingchil...  15.0
# 2  https://www.hamogelo.gr/gr/el/ajax/missingchil...   4.0
# 3  https://www.hamogelo.gr/gr/el/ajax/missingchil...  13.0
# 4  https://www.hamogelo.gr/gr/el/ajax/missingchil...  15.0

# %% [markdown]
# Αποθηκεύω το df μου σε csv.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
df.to_csv("/content/gdrive/My Drive/Colab Notebooks/amber_alert.csv", sep='t', encoding='utf-8', index=False)

# %% [markdown]
# https://raw.githubusercontent.com/SophiaPapach/datajour/main/amber_alert.csv

# %%
#df =pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/amber_alert.csv", sep='t')

# %%
df= pd.read_csv("https://raw.githubusercontent.com/SophiaPapach/datajour/main/amber_alert.csv", sep='t')

# %%
df.head()
# Out:
#                         Name Date Missing   Birthdate     Eyes          Hair  \
# 0          ΜΑΡΙΑ-ΑΥΓΟΥΣΤΑ Σ.   2022-01-21  2008-10-02  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΚΟΝΤΑ
# 1  ΜΠΙΜΠΙ ΑΜΙΝΑ ΣΑΧΑΜΠ ΖΑΝΤΑ   2022-01-13  2006-04-28  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 2              ΧΙΤΖΑΖΙ ΑΘΗΝΑ   2021-11-21  2017-02-23  ΚΑΣΤΑΝΑ  ΜΑΥΡΑ ΜΑΚΡΙΑ
# 3              ΑΛΕΞΑΝΔΡΟΣ Δ.   2021-11-19  2008-01-15  ΚΑΣΤΑΝΑ       ΚΑΣΤΑΝΑ
# 4                  ΜΙΧΑΗΛ Γ.   2021-11-17  2006-04-08     ΜΠΛΕ         ΜΑΥΡΑ
#
#                                             Info Url   Age
# 0  https://www.hamogelo.gr/gr/el/ajax/missingchil...  13.0
# 1  https://www.hamogelo.gr/gr/el/ajax/missingchil...  15.0
# 2  https://www.hamogelo.gr/gr/el/ajax/missingchil...   4.0
# 3  https://www.hamogelo.gr/gr/el/ajax/missingchil...  13.0
# 4  https://www.hamogelo.gr/gr/el/ajax/missingchil...  15.0

# %%
df.dtypes
# Out:
# Name             object
# Date Missing     object
# Birthdate        object
# Eyes             object
# Hair             object
# Info Url         object
# Age             float64
# dtype: object

# %%
df['Age']= df['Age'].astype(np.int64)

# %% [markdown]
# * Ποιος είναι ο μέσος όρος ηλικίας των παιδιών που είναι εξαφανισμένα αυτή την στιγμή;

# %%
df['Age'].mean()
# Out:
# 10.327272727272728

# %%
import seaborn as sns
sns.set_theme(palette="pastel")

# %%
df['Age'].value_counts().head()
# Out:
# 15    7
# 14    6
# 13    5
# 4     5
# 6     4
# Name: Age, dtype: int64

# %%
#εκει που εχω βάλει 3, βάζεις οποιο αριθμο απο value counts θες να μπει στα others
s=df['Age'].value_counts()
s.groupby(np.where(s>=3,s.index,'other')).sum().plot(kind='pie', shadow = True, figsize=(5,5), autopct='%1.0f%%', title='Ηλικίες Εξαφανισμένων Παιδιών')
plt.suptitle('Source Of Data: Amber-Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber-Alert Hellas')

# %%
df.loc[df['Age'].between(0,3), 'age_group'] = '0+'
df.loc[df['Age'].between(3,4), 'age_group'] = '3+'
df.loc[df['Age'].between(5,10), 'age_group'] = '5+'
df.loc[df['Age'].between(11,14), 'age_group'] = '10+'
df.loc[df['Age'].between(15,20), 'age_group'] = '15+'
df.loc[df['Age'].between(20,30), 'age_group'] = '20+'

# %%
ag=df['age_group'].value_counts().plot(kind='pie', shadow = True, figsize=(5,5), autopct='%1.0f%%', title='Εξαφανισμένα Παιδιά ανα ηλικιακή ομάδα')
plt.suptitle('Source Of Data: Amber - Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber - Alert Hellas')

# %% [markdown]
# * Ποια χρονιά έχει τις περισσότερες ενεργές εξαφανίσεις παιδιών;

# %%
pd.DatetimeIndex(df['Date Missing']).year.value_counts()
# Out:
# 2015    12
# 2019     8
# 2021     7
# 2011     5
# 2020     3
# 2016     3
# 2008     3
# 2022     2
# 2018     2
# 2007     2
# 2004     2
# 1992     1
# 1991     1
# 2009     1
# 2000     1
# 2005     1
# 1981     1
# Name: Date Missing, dtype: int64

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params, palette="pastel")
#sns.set_theme(style="whitegrid", rc=custom_params)

# %%
pd.DatetimeIndex(df['Date Missing']).year.value_counts(ascending=True).plot(kind='barh', title='Ενεργές Εξαφανίσεις παιδιών ανα έτος', color= np.random.rand(3))
plt.suptitle('Source Of Data: Amber Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber Alert Hellas')

# %%
plt.figure(figsize=(12,5))
sns.countplot(x=pd.DatetimeIndex(df['Date Missing']).year).set(title='Ενεργές Εξαφανίσεις Παιδιών ανα έτος')
plt.suptitle('Source Of Data: Amber Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber Alert Hellas')

# %% [markdown]
# Ψάχνω να δω για το 2015 που εχει τις περισσότερες εξαφανισεις περισσότερες πληροφορίες όπως τα ονόματα των παιδιών.. Και από το παρακάτω βλέπω ότι όλα είναι μετανάστες- πρόσφυγες, δεν έχουν ελληνικό όνομα.

# %%
df['Year'] = pd.DatetimeIndex(df['Date Missing']).year
df[df['Year'] ==2015]['Name']
# Out:
# 25                        ΑΜΙΡ ΓΙΑΣΙΜ ΣΑΜΟ
# 26                            ΡΟΝΤΕΡ ΟΘΜΑΝ
# 27                              ΑΛΝΤ ΟΘΜΑΝ
# 28                            ΡΟΝΤΙ ΤΖΑΜΙΛ
# 29                            ΣΟΛΙΝ ΤΖΑΜΙΛ
# 30                             ΡΟΝΙ ΤΖΑΜΙΛ
# 31                          ΜΑΣΣΟΥΝ ΤΖΑΜΙΛ
# 32                         ΜΟΧΑΜΑΝΤ ΤΖΑΜΙΛ
# 33            ΜΟΧΑΜΕΤ και ΑΜΠΑΣ ΑΛΚΑΦΑΝΤΖΙ
# 34       ΑΓΙΑ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ
# 35    ΣΑΓΙΑΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ
# 36     ΑΧΜΕΝΤ ΑΚΙΛ ΑΜΠΝΤΟΥΛΒΑΧΙΝΤ ΑΛΣΑΕΝΤΙ
# Name: Name, dtype: object

# %% [markdown]
# * Ποια εποχή / μήνα έχουμε τις περισσότερες εξαφανίσεις;

# %%
pd.DatetimeIndex(df['Date Missing']).month.value_counts()
# Out:
# 9     8
# 11    7
# 10    7
# 1     5
# 12    5
# 7     5
# 5     4
# 8     4
# 6     4
# 4     4
# 2     2
# Name: Date Missing, dtype: int64

# %%
pd.DatetimeIndex(df['Date Missing']).month.value_counts(ascending=True).plot(kind='barh', title='Ενεργές Εξαφανίσεις παιδιών ανα μήνα')
plt.suptitle('Source Of Data: Amber Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber Alert Hellas')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=pd.DatetimeIndex(df['Date Missing']).month).set(title='Ενεργές Εξαφανίσεις Παιδιών ανα μηνα')
plt.suptitle('Source Of Data: Amber Alert Hellas',fontsize=12, y=0)
# Out:
# Text(0.5, 0, 'Source Of Data: Amber Alert Hellas')

# %% [markdown]
# * Ποιο είναι η μικρότερη ηλικία εξαφανισμένου παιδιού και ποια η μεγαλύτερη;

# %%
#df['Age'].max() κάνω το απο κάτω για να δω και τα στοιχεία του παιδιού όχι μόνο τον αριθμό της ηλικίας
df[df['Age']== df['Age'].max()]
# Out:
#                         Name   Birthdate   Eyes   Hair  \
# Date Missing
# 2011-09-27    LEONG JIN KUOK  1983-08-22  Μαύρα  Μαύρα
#
#                                                        Info Url  Age
# Date Missing
# 2011-09-27    https://www.hamogelo.gr/gr/el/ajax/missingchil...   28

# %%
df[df['Age']== df['Age'].min()]
# Out:
#                       Name   Birthdate           Eyes             Hair  \
# Date Missing
# 2008-09-07    MATEO DULLIA  2007-09-28  Γκριζοπράσινα  Καστανά ανοιχτά
#
#                                                        Info Url  Age
# Date Missing
# 2008-09-07    https://www.hamogelo.gr/gr/el/ajax/missingchil...    0
